# %% [markdown]
# ### Combine Award Sources to Create Single Awards Table
#
# **Priority Order (lower = higher priority):**
# - 0: GTR Project Awards (authoritative for UK grants, full metadata)
# - 1: Crossref Awards (rich metadata from Crossref)
# - 2: Backfill Awards (extracted from publication funding acknowledgements)
# - 3: NIH Awards (US NIH grants with full metadata)
# - 3: NSF Awards (US NSF grants with full metadata)
# - 3: NSERC Awards (Canadian NSERC grants with full metadata)
# - 3: GTR Awards (legacy publication-based, for work linkage only)
# - 4: Gates Foundation Awards (Bill & Melinda Gates Foundation committed grants)
# - 5: SSHRC Awards (Social Sciences and Humanities Research Council of Canada)
# - 6: ANR Awards (Agence Nationale de la Recherche - French National Research Agency)
# - 7: CIHR Awards (Canadian Institutes of Health Research)
# - 8: CFI Awards (Canada Foundation for Innovation)
# - 9: Vinnova Awards (Sweden's Innovation Agency)
# - 10: KAKEN Awards (Japan Society for the Promotion of Science - Grants-in-Aid)
# - 11: NWO Awards (Dutch Research Council)
# - 12: NHMRC Awards (National Health and Medical Research Council - Australia)
# - 13: NIHR Awards (National Institute for Health and Care Research - UK)
# - 14: SNSF Awards (Swiss National Science Foundation)
# - 15: Swedish Research Council Awards (Vetenskapsrådet)
# - 16: Formas Awards (Swedish Research Council for Sustainable Development)
# - 17: Forte Awards (Swedish Research Council for Health, Working Life and Welfare)
# - 18: DFG Awards (Deutsche Forschungsgemeinschaft - German Research Foundation)
# - 19: FAPESP Awards (Fundação de Amparo à Pesquisa do Estado de São Paulo - São Paulo Research Foundation)
# - 20: ARC Awards (Australian Research Council)
# - 21: ERC Awards (European Research Council)
# - 22: Wellcome Trust Awards (Wellcome Trust - UK philanthropic funder)
# - 23: NASA Awards (NASA - US space agency research grants)
# - 24: Academy of Finland Awards (Research Council of Finland - Finnish research funder)
# - 25: DOE Awards (U.S. Department of Energy research grants)
# - 26: DOD Awards (U.S. Department of Defense research grants)
# - 27: European Commission Awards (EC Horizon 2020, Horizon Europe, FP7 research grants)
# - 28: Innovate UK Awards (UK business innovation grants)
# - 29: FWF Awards (Austrian Science Fund research grants)
# - 30: Independent Research Fund Denmark Awards (Danmarks Frie Forskningsfond - Danish research grants)
# - 31: AEI Awards (Agencia Estatal de Investigación - Spanish State Research Agency)
# - 32: NCN Awards (Narodowe Centrum Nauki - Polish National Science Centre)
# - 33: ISCIII Awards (Instituto de Salud Carlos III - Spanish biomedical research)
# - 34: GACR Awards (Grantová Agentura České Republiky - Czech Science Foundation)
# - 35: ANID Awards (Agencia Nacional de Investigación y Desarrollo - Chilean research agency)
# - 36: BMBF Awards (Bundesministerium für Bildung und Forschung - German Federal Ministry of Education and Research)
# - 37: IDRC Awards (International Development Research Centre — Canada-based, Global South focus, IATI activities)
# - 38: Carl-Zeiss-Stiftung Awards (German foundation funding AI, life sciences, resource efficiency)
# - 39: Templeton Awards (John Templeton Foundation — US philanthropic, ~5,956 grants)
# - 40: Rockefeller Awards (Rockefeller Foundation — US philanthropic, ~1,511 grants)
# - 41: Arnold Ventures Awards (formerly Laura and John Arnold Foundation, ~2,632 grants)
# - 42: Nobel Prize Awards (PRIZE PATTERN — laureates of Physics, Chemistry, Economic Sciences, Physiology or Medicine; awarding body = Royal Swedish Academy of Sciences or Karolinska Institutet)
# - 43: Argentina MINCYT Awards (Argentine projects from datos.gob.ar; one row per project, attributed to ANPCYT / CONICET / INTA via `proyecto_fuente`)
# - 44: HHMI Awards (Howard Hughes Medical Institute investigators — agent-browser scraped; amount NULL because HHMI does not disclose per-investigator funding)
# - 45: Open Society Foundations Awards (international philanthropic; Playwright scrape of grants/past listing)
# - 46: RWJF Awards (Robert Wood Johnson Foundation; ~31,717 grants 1972-2026 totaling $14.4B; Playwright scrape of grants explorer)
# - 47: Wolf Prize Awards (PRIZE PATTERN — Wolf Foundation; 391 laureates 1978-present across 9 fields)
# - 48: Lasker Awards (PRIZE PATTERN — Lasker Foundation; biomedical, BASIC/CLINICAL/SPECIAL categories)
# - 49: Kavli Prize Awards (PRIZE PATTERN — Kavli Foundation; biennial, astrophysics/nanoscience/neuroscience)
# - 59: USGS Awards (GRANT PATTERN — U.S. Geological Survey, F4320332183; Department of the Interior subtier, USAspending bulk download FY2001-2025; priority 59 chosen because 50-58 are reserved for in-flight PRs #80-#88)
#
# When the same award appears in multiple sources, the highest priority source wins.

# %%
# %sql
CREATE OR REPLACE TABLE openalex.awards.openalex_awards
USING delta
AS
WITH award_aggregates AS (
  SELECT
    CAST(REPLACE(award.id, 'https://openalex.org/G', '') AS BIGINT) as award_id,
    TRANSFORM(
      SORT_ARRAY(COLLECT_LIST(DISTINCT id)), 
      w -> CONCAT('https://openalex.org/W', w)
    ) as funded_outputs,
    COUNT(DISTINCT id) as funded_outputs_count
  FROM openalex.works.openalex_works
  LATERAL VIEW explode(awards) as award
  WHERE size(awards) > 0
  GROUP BY award.id
),
deduplicated_awards AS (
  SELECT 
    * EXCEPT(priority, row_num)
  FROM (
    SELECT 
      *,
      ROW_NUMBER() OVER (PARTITION BY id ORDER BY priority ASC) as row_num
    FROM openalex.awards.openalex_awards_raw
  )
  WHERE row_num = 1
)
SELECT 
  da.*,
  SLICE(COALESCE(aa.funded_outputs, ARRAY()), 1, 100) as funded_outputs,
  COALESCE(aa.funded_outputs_count, 0) as funded_outputs_count
FROM 
  deduplicated_awards da
  LEFT JOIN award_aggregates aa 
    ON da.id = aa.award_id
